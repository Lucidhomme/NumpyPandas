# %% [markdown]
# * fillna : NaN을 값을 원하는 값으로 변경할 수 있다

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_df = pd.DataFrame({
    'A' : [1,3,4,3,4],
    'B' : [2,3,1,2,3],
    'C' : [1,5,2,4,4]
})
sample_df
# Out:
#    A  B  C
# 0  1  2  1
# 1  3  3  5
# 2  4  1  2
# 3  3  2  4
# 4  4  3  4

# %%
sample_df.iloc[2,2] = np.nan

# %%
sample_df
# Out:
#    A  B    C
# 0  1  2  1.0
# 1  3  3  5.0
# 2  4  1  NaN
# 3  3  2  4.0
# 4  4  3  4.0

# %%
sample_df.apply(pd.value_counts).fillna(0.0)
# Out:
#        A    B    C
# 1.0  1.0  1.0  1.0
# 2.0  0.0  2.0  0.0
# 3.0  2.0  2.0  0.0
# 4.0  2.0  0.0  2.0
# 5.0  0.0  0.0  1.0

# %% [markdown]
# * astype : 자료형을 바꾸는 기능

# %%
sample_df.apply(pd.value_counts).fillna(0).astype(int)
# Out:
#      A  B  C
# 1.0  1  1  1
# 2.0  0  2  0
# 3.0  2  2  0
# 4.0  2  0  2
# 5.0  0  0  1

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic', engine='python')

# %%
# 타이타닉 승객 중 나이를 명시하지 않은 고객은 나이를 명시한 고객의 평균 나이 값으로 대체
titanic['age'] = titanic['age'].fillna(titanic['age'].mean())
# print('타이타닉 df의 age칼럼 결측치 수 : ', pd.isnull(titanic['age']).sum())
display(titanic['age'].head(20))

# 타이타닉 승객에 대해 나이와 성별에 의한 age_gender_cat 열을 만들고
# 조건 1. 성별을 나타내는 문자열 male 또는 female로 시작한다
# 조건 2. 성별을 나타내는 문자열 뒤에 나이를 나타내는 문자열로 변경하라
# 조건 3. 예시) 남성의 나이가 27이라면 -> male27 
titanic['age_gender_cat'] = titanic['sex'] + titanic['age'].astype(int).apply(str)
display(titanic['age_gender_cat'].head(20))
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    29.699118
# 18    31.000000
# 19    29.699118
# Name: age, dtype: float64
# 0       male22
# 1     female38
# 2     female26
# 3     female35
# 4       male35
# 5       male29
# 6       male54
# 7        male2
# 8     female27
# 9     female14
# 10     female4
# 11    female58
# 12      male20
# 13      male39
# 14    female14
# 15    female55
# 16       male2
# 17      male29
# 18    female31
# 19    female29
# Name: age_gender_cat, dtype: object

# %% [markdown]
# # 데이터프레임 인덱스 조작하는 방법
# * set_index : 기존 행 인덱스를 제거하고 데이터 열 중 하나를 인덱스로 설정
# * reset_index : 기존 행 인덱스를 제거하고 인덱스를 데이터 열 추가

# %%
np.random.seed(100)
index_df = pd.DataFrame(np.vstack([list('ABCDE'),
                                  np.round(np.random.rand(3,5),2)]).T,
                       columns=['col01', 'col02', 'col03', 'col04'])
index_df
# Out:
#   col01 col02 col03 col04
# 0     A  0.54  0.12  0.89
# 1     B  0.28  0.67  0.21
# 2     C  0.42  0.83  0.19
# 3     D  0.84  0.14  0.11
# 4     E   0.0  0.58  0.22

# %%
index_df2 = index_df.set_index('col01') # 열 중 하나를 인덱스로 변경
index_df2
# Out:
#       col02 col03 col04
# col01
# A      0.54  0.12  0.89
# B      0.28  0.67  0.21
# C      0.42  0.83  0.19
# D      0.84  0.14  0.11
# E       0.0  0.58  0.22

# %%
index_df3 = index_df2.set_index('col02')
index_df3
# Out:
#       col03 col04
# col02
# 0.54   0.12  0.89
# 0.28   0.67  0.21
# 0.42   0.83  0.19
# 0.84   0.14  0.11
# 0.0    0.58  0.22

# %%
index_df2.reset_index() # 원래 인덱스를 열로 대체하고 인덱스 새로 생성
# Out:
#   col01 col02 col03 col04
# 0     A  0.54  0.12  0.89
# 1     B  0.28  0.67  0.21
# 2     C  0.42  0.83  0.19
# 3     D  0.84  0.14  0.11
# 4     E   0.0  0.58  0.22

# %%
index_df2.reset_index(drop=True) #원래 인덱스 제거하고 대체
# Out:
#   col02 col03 col04
# 0  0.54  0.12  0.89
# 1  0.28  0.67  0.21
# 2  0.42  0.83  0.19
# 3  0.84  0.14  0.11
# 4   0.0  0.58  0.22

# %%
# 5명의 학생의 국어, 영어, 수학 점수를 나타내는 데이터프레임을 만든다.
# 1. 학생 이름을 나타내는 열을 포함시키지 않고 
# 데이터프레임 df_score1 을 생성한 후, 
# df_score1.index 속성에 학생 이름을 나타내는 열을 지정하여 인덱스를 지정한다.
# reset_index 명령으로 이 인덱스 열을 명령으로 
# 일반 데이터열로 바꾸여 데이터프레임 df_score2을 만든다.
df_score1 = pd.DataFrame({
    '국어' : [90,95,85,80,75],
    '영어' : [92,65,75,82,93],
    '수학' : [81,85,22,74,64]
})

df_score1.index = ['김씨','이씨','박씨','최씨','정씨']
df_score1.index.name = '이름'
df_score2 = df_score1.reset_index()
display(df_score2)


# 2.학생 이름을 나타내는 열이 일반 데이터 열을 포함하는 데이터프레임 df_score2에 
# set_index 명령을 적용하여 다시 학생 이름을 나타내는 열을 인덱스로 변경한다.
df_score3 = df_score2.set_index('이름')
display(df_score3)
# Out:
#    이름  국어  영어  수학
# 0  김씨  90  92  81
# 1  이씨  95  65  85
# 2  박씨  85  75  22
# 3  최씨  80  82  74
# 4  정씨  75  93  64
#     국어  영어  수학
# 이름
# 김씨  90  92  81
# 이씨  95  65  85
# 박씨  85  75  22
# 최씨  80  82  74
# 정씨  75  93  64

# %% [markdown]
# * np.random.randint : 정수의 난수 1개 생성
# * np.random.rand : 0~1 사이의 분포된 난수 생성
# * np.random.randn : 표준정규분포에서 난수 생성

# %%
import numpy as np

# %%
np.random.randint(6) # 0 ~ 5
# Out:
# 3

# %%
np.random.randint(1,20) # 1~19
# Out:
# 5

# %%
np.random.rand(6) # 0 ~ 1
# Out:
# array([0.12665424, 0.07898787, 0.31135313, 0.63238359, 0.69935892,
#        0.64196495])

# %%
np.random.rand(3,2)
# Out:
# array([[0.92002378, 0.29887635],
#        [0.56874553, 0.17862432],
#        [0.5325737 , 0.64669147]])

# %%
np.random.randn(6) # 정규분포 난수
# Out:
# array([ 0.24652489, -1.08417396, -2.3815826 , -0.4363488 , -2.07241186,
#        -1.29543984])

# %%
np.random.randn(3,2)
# Out:
# array([[-0.46402358, -0.05702664],
#        [ 0.27592974,  1.49451522],
#        [ 0.56682064, -2.30337426]])

# %% [markdown]
# # DataFrame merge

# %%
data1 = {
    '학번' : [1,2,3,4],
    '이름' : ['섭섭해','김한준','김선림','최호진'],
    '학년' : [2,4,1,3]
}

data2 = {
    '학번' : [1,2,4,5],
    '학과' : ['Computer Science','Math','Math','Computer Science'],
    '학점' : [2.4,4.5,3.4,4.2]
}

# %%
stu_df = pd.DataFrame(data1)
major_df = pd.DataFrame(data2)
display(stu_df)
display(major_df)
# Out:
#    학번   이름  학년
# 0   1  섭섭해   2
# 1   2  김한준   4
# 2   3  김선림   1
# 3   4  최호진   3
#    학번                학과   학점
# 0   1  Computer Science  2.4
# 1   2              Math  4.5
# 2   4              Math  3.4
# 3   5  Computer Science  4.2

# %%
pd.merge(stu_df,major_df)
# Out:
#    학번   이름  학년                학과   학점
# 0   1  섭섭해   2  Computer Science  4.2
# 1   2  김한준   4              Math  3.4
# 2   3  김선림   1              Math  4.5
# 3   4  최호진   3  Computer Science  2.4

# %%
pd.merge(stu_df, major_df, on='학번' , how='inner') # 공통의 컬럼 on사용
# Out:
#    학번   이름  학년                학과   학점
# 0   1  섭섭해   2  Computer Science  2.4
# 1   2  김한준   4              Math  4.5
# 2   4  최호진   3              Math  3.4

# %%
pd.merge(stu_df, major_df, on='학번' , how='left')
# Out:
#    학번   이름  학년                학과   학점
# 0   1  섭섭해   2  Computer Science  2.4
# 1   2  김한준   4              Math  4.5
# 2   3  김선림   1               NaN  NaN
# 3   4  최호진   3              Math  3.4

# %%
pd.merge(stu_df, major_df, on='학번' , how='right')
# Out:
#    학번   이름   학년                학과   학점
# 0   1  섭섭해  2.0  Computer Science  2.4
# 1   2  김한준  4.0              Math  4.5
# 2   4  최호진  3.0              Math  3.4
# 3   5  NaN  NaN  Computer Science  4.2

# %%
pd.merge(stu_df, major_df, on='학번' , how='outer')
# Out:
#    학번   이름   학년                학과   학점
# 0   1  섭섭해  2.0  Computer Science  2.4
# 1   2  김한준  4.0              Math  4.5
# 2   3  김선림  1.0               NaN  NaN
# 3   4  최호진  3.0              Math  3.4
# 4   5  NaN  NaN  Computer Science  4.2

# %%
data1 = {
    '학번' : [1,2,3,4],
    '이름' : ['섭섭해','김한준','김선림','최호진'],
    '학년' : [2,4,1,3]
}

data2 = {
    '과목코드' : [1,2,4,5],
    '학과' : ['Computer Science','Math','Math','Computer Science'],
    '학점' : [2.4,4.5,3.4,4.2]
}

# %%
stu_df = pd.DataFrame(data1)
major_df = pd.DataFrame(data2)
display(stu_df)
display(major_df)
# Out:
#    학번   이름  학년
# 0   1  섭섭해   2
# 1   2  김한준   4
# 2   3  김선림   1
# 3   4  최호진   3
#    과목코드                학과   학점
# 0     1  Computer Science  2.4
# 1     2              Math  4.5
# 2     4              Math  3.4
# 3     5  Computer Science  4.2

# %%
pd.merge(stu_df, major_df, left_on = '학번', right_on ='과목코드', how='inner') #컬럼의 이름이 동일하지않을때
# Out:
#    학번   이름  학년  과목코드                학과   학점
# 0   1  섭섭해   2     1  Computer Science  2.4
# 1   2  김한준   4     2              Math  4.5
# 2   4  최호진   3     4              Math  3.4

# %%
iris_df01 = pd.DataFrame({
    '품종' : ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎길이' : [1.4, 1.3, 1.5, 1.3]},
     columns = ['품종','꽃잎길이'])
iris_df01
# Out:
#           품종  꽃잎길이
# 0     setosa   1.4
# 1     setosa   1.3
# 2  virginica   1.5
# 3  virginica   1.3

# %%
iris_df02 = pd.DataFrame({
    '품종' : ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비' : [0.4, 0.3, 0.5, 0.3]},
     columns = ['품종','꽃잎너비'])
iris_df02
# Out:
#            품종  꽃잎너비
# 0      setosa   0.4
# 1   virginica   0.3
# 2   virginica   0.5
# 3  versicolor   0.3

# %%
pd.merge(iris_df01, iris_df02)
# Out:
#           품종  꽃잎길이  꽃잎너비
# 0     setosa   1.4   0.4
# 1     setosa   1.3   0.4
# 2  virginica   1.5   0.3
# 3  virginica   1.5   0.5
# 4  virginica   1.3   0.3
# 5  virginica   1.3   0.5

# %%
iris_df01 = pd.DataFrame({
    '품종' : ['setosa', 'setosa', 'virginica', 'virginica'],
    '꽃잎너비' : [1.4, 1.3, 1.5, 1.3],
    '개화시기' : ['202012','202010','202009','202010']})

iris_df02 = pd.DataFrame({
    '품종' : ['setosa', 'virginica', 'virginica', 'versicolor'],
    '꽃잎너비' : [0.4, 0.3, 0.5, 0.3]})

# %%
pd.merge(iris_df01, iris_df02, on='품종')
# Out:
#           품종  꽃잎너비_x    개화시기  꽃잎너비_y
# 0     setosa     1.4  202012     0.4
# 1     setosa     1.3  202010     0.4
# 2  virginica     1.5  202009     0.3
# 3  virginica     1.5  202009     0.5
# 4  virginica     1.3  202010     0.3
# 5  virginica     1.3  202010     0.5

# %% [markdown]
# * 컬럼인덱스가 아닌 인덱스를 기준으로 병합한다면?
# * left_index, right_index

# %%
pop_df01 = pd.DataFrame({
    'city' : ['seoul', 'seoul', 'seoul', 'busan', 'busan'],
    'year' : [2010, 2005, 2020, 2018, 2015],
    'pop' : [1234567, 2345677, 2132142, 1231231, 3332221]
})
pop_df01
# Out:
#     city  year      pop
# 0  seoul  2010  1234567
# 1  seoul  2005  2345677
# 2  seoul  2020  2132142
# 3  busan  2018  1231231
# 4  busan  2015  3332221

# %%
pop_df02    = pd.DataFrame( np.arange(12).reshape((6,2)) , 
    index   = [['busan' , 'busan', 'seoul' , 'seoul' , 'seoul' , 'seoul'] , 
               [2010, 2005, 2020, 2018, 2015, 2010]] , 
    columns =  ['col01','col02']
)
pop_df02
# Out:
#             col01  col02
# busan 2010      0      1
#       2005      2      3
# seoul 2020      4      5
#       2018      6      7
#       2015      8      9
#       2010     10     11

# %%
pd.merge(pop_df01 , pop_df02 , left_on=['city', 'year'], right_index=True)
# Out:
#     city  year      pop  col01  col02
# 0  seoul  2010  1234567     10     11
# 2  seoul  2020  2132142      4      5

# %%
data1 = { "이름" : ["이지안","박동훈","이순신","강감찬"],
          "학년" : [2,4,1,3]}

data2 = { "학과" : ["CS","MATH","MATH","CS"],
          "학점" : [3.4,2.9,4.5,1.2]}

# %%
df01 = pd.DataFrame(data1, index=[1,2,3,4])
df02 = pd.DataFrame(data2, index=[1,2,4,5])

# %%
display(df01)
display(df02)
# Out:
#     이름  학년
# 1  이지안   2
# 2  박동훈   4
# 3  이순신   1
# 4  강감찬   3
#      학과   학점
# 1    CS  3.4
# 2  MATH  2.9
# 4  MATH  4.5
# 5    CS  1.2

# %%
merge_df = pd.merge(df01, df02, right_index = True, left_index = True)

# %%
# join
df01.join(df02, how = 'inner')
# Out:
#     이름  학년    학과   학점
# 1  이지안   2    CS  3.4
# 2  박동훈   4  MATH  2.9
# 4  강감찬   3  MATH  4.5

# %%
merge_df
# Out:
#     이름  학년    학과   학점
# 1  이지안   2    CS  3.4
# 2  박동훈   4  MATH  2.9
# 4  강감찬   3  MATH  4.5

# %%
merge_df.iloc[2]
# Out:
# 이름     강감찬
# 학년       3
# 학과    MATH
# 학점     4.5
# Name: 4, dtype: object

# %%
merge_df.loc[2]
# Out:
# 이름     박동훈
# 학년       4
# 학과    MATH
# 학점     2.9
# Name: 2, dtype: object
