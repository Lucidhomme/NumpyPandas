# %% [markdown]
# # 학습목표
# * 시각화 패키지 matplolib
# * 서브 패키지 pyplot
# * seaborn
# * 분석된 내용을 시각화
# * Pandas 시각화 기능

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %matplotlib inline

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# * line plot : 데이터가 시간, 순서 등에 따라 어떻게 변화하는지를 보여주는 플롯

# %%
plt.title('line plot')
plt.plot([1,4,9,16]) #리스트나 array 가능
plt.show()

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40], [1,4,9,16], 'go--')
plt.xlabel('x라벨')
plt.ylabel('y라벨')

plt.show()

# %% [markdown]
# * option(color, marker, style)
# * 약어 -> "g"(칼라),"o"(마커), "--"(스타일) 위 참조

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40], [1,4,9,16],
        c='b',
        lw=5, ls='--', marker= 'o', ms=15, mec='g', mew=5, mfc='r')
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# * tick(xticks, yticks) : x축과 y축 나타내는 값 설정

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y = np.cos(X)
plt.plot(X,Y)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
plt.grid(True)
plt.show()

# %% [markdown]
# * 여러개의 라인 플롯을 그린다면?

# %%
data = np.arange(0. , 5.0, 0.2)
data
plt.title('여러개의 라인 플롯')
plt.plot(data, data, 'r--', data, data**2, 'b--', data, data**3, 'g--')
plt.show()

# %%
plt.title('라인을 겹쳐 그리기')
plt.plot([1,4,9,16],
        c='b',
        lw=5, ls='--', marker= 'o', ms=15, mec='g', mew=5, mfc='r')
plt.plot([9,16,4,1],
        c='k',
        lw=3, ls='--', marker= 's', ms=10, mec='m', mew=5, mfc='c')
plt.legend(loc=0)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y_C, Y_S = np.cos(X) , np.sin(X)
plt.plot(X, Y_C, ls='--', label= 'cosine')
plt.plot(X, Y_S, ls='--', label='sin')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# * matplotlib 그림을 그리는객체, Figure, Axes, Axis 객체를 포함하고 있다.
# * Figure -> 그림이 그려지는 종이 뜻
# * Axes -> 플롯
# * Axis -> 축

# %%
np.random.seed(100)
plt.figure(figsize=(10,2)) #액자 사이즈
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# * subplot(2,1,1)
# * subplot(2,1,2)

# %%
X1 = np.linspace(0.0, 5.0)
Y1 = np.cos(2 * np.pi * X1) * np.exp(-X1)
print(X1)
print(Y1)
X2 = np.linspace(0.0, 2.0)
Y2 = np.cos(2 * np.pi * X2)
print(X2)
print(Y2)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [ 1.          0.72367065  0.2320026  -0.25429107 -0.55721991 -0.59913951
#  -0.41280458 -0.10893327  0.17893551  0.34780448  0.35748852  0.23380958
#   0.04690762 -0.12275601 -0.21591812 -0.21241248 -0.13137462 -0.01694367
#   0.08259904  0.1333648   0.12567347  0.0731473   0.00339549 -0.05472957
#  -0.08198104 -0.07402828 -0.04029719  0.00203856  0.03580865  0.05016511
# ...

# %%
axes01 = plt.subplot(2,1,1) #2행 1열
plt.plot(X1, Y1)
plt.title('subplot 01')

axes02 = plt.subplot(2,1,2) 
plt.plot(X2, Y2)
plt.title('subplot 02')

plt.tight_layout() # 자동으로 간격을 맞춰주는 역할

plt.show()

# %% [markdown]
# # 플롯의 유형
# * line plot
# * scatter plot
# * contour plot
# * surface plot
# * bar plot
# * histogram plot
# * box plot

# %%
# bar plot
# x 데이터는 카테고리 값인 경우가 대부분이다

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib as mpl

# %matplotlib inline

Y = [2,3,1]
X = np.arange(len(Y))

xlabel = ['1등실', '2등실', '3등실']
plt.title('bar plot')
plt.bar(X, Y) #가로방향
plt.xticks(X, xlabel)
plt.yticks(sorted(Y))
plt.xlabel('선실등급')
plt.ylabel('생존자수')
plt.show()

# %%
# bar plot
# x 데이터는 카테고리 값인 경우가 대부분이다

import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib as mpl

# %matplotlib inline

Y = [2,3,1]
X = np.arange(len(Y))

xlabel = ['1등실', '2등실', '3등실']
plt.title('bar plot')
plt.barh(X, Y) #가로방향
plt.xticks(X, xlabel)
plt.yticks(sorted(Y))
plt.xlabel('선실등급')
plt.ylabel('생존자수')
plt.show()

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
iris.rename(columns = {iris.columns[0] : 'SL',
                       iris.columns[1] : 'SW',
                       iris.columns[2] : 'PL',
                       iris.columns[3] : 'PW',
                       iris.columns[4] : 'Y'}, inplace = True)

# %%
iris.head()
# Out:
#     SL   SW   PL   PW       Y
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
iris[['SL', 'SW']][ : 5]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6

# %%
# EDA
# 종을 기준으로 그룹화를 하여 각 그룹의 평균을 구해보자
species_mean = iris.groupby(['Y']).mean()
species_mean
# Out:
#                SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.columns.name = 'SP'
species_mean
# Out:
# SP             SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.T.plot.bar(rot=0) #축을 범주로 가져가고싶어서 T로 전치함
plt.title('각 변수별 평균')
plt.ylabel('평균')
plt.xlabel('변수')
plt.ylim(0,8)
plt.show()

# %%
species_mean.plot.bar(rot=0)

# %% [markdown]
# * iris.boxplot

# %%
iris[['SL', 'Y']].head()
# Out:
#     SL       Y
# 0  5.1  setosa
# 1  4.9  setosa
# 2  4.7  setosa
# 3  4.6  setosa
# 4  5.0  setosa

# %%
iris[['SW', 'Y']].boxplot(by='Y')
plt.title('종에 따른 SW Boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

ax = axes.flatten()

iris[['SL', 'Y']].boxplot(by='Y', ax=ax[0])
plt.title('종에 따른 SL Boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['SW', 'Y']].boxplot(by='Y', ax=ax[1])
plt.title('종에 따른 SW Boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['PL', 'Y']].boxplot(by='Y', ax=ax[2])
plt.title('종에 따른 PL Boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['PW', 'Y']].boxplot(by='Y', ax=ax[3])
plt.title('종에 따른 PW Boxplot')
plt.xlabel('type')
plt.ylabel('cm')

# %% [markdown]
# # car_mpg.xls[실습]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
xls = pd.ExcelFile('./data/car_mpg.xlsx', sep=',')

# %%
data_df = xls.parse(xls.sheet_names[0])
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
data_df['fl']
# Out:
# 1      p
# 2      p
# 3      p
# 4      p
# 5      p
# 6      p
# 7      p
# 8      p
# 9      p
# 10     p
# 11     p
# 12     p
# 13     p
# 14     p
# 15     p
# 16     p
# 17     p
# 18     p
# 19     r
# 20     e
# 21     r
# 22     r
# 23     r
# 24     p
# 25     p
# 26     p
# 27     p
# 28     p
# 29     r
# 30     e
#       ..
# 205    r
# 206    r
# 207    r
# 208    r
# 209    r
# 210    p
# 211    p
# 212    r
# 213    d
# 214    r
# 215    r
# 216    p
# 217    p
# 218    r
# 219    r
# 220    r
# 221    r
# 222    d
# 223    d
# 224    r
# 225    r
# 226    r
# 227    r
# 228    p
# 229    p
# 230    p
# 231    p
# 232    p
# 233    p
# 234    p
# Name: fl, Length: 234, dtype: object

# %%
row, col = data_df.shape
print('row : ', row)
print('col : ', col)
# Out:
# row :  234
# col :  11

# %%
# 기술통계 값
data_df.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# * 양적자료 : 요약정보에 집계가 되는 컬럼으로 관측된 값이 수치형태의 속성을 가지는 자료
# * 양적자료의 시각화 : boxplot
# * 배기량, 생산년도, 실린더, 실린더 개수, 도시연비, 고속도로연비
#
# * 질적자료 : 범주 또는 순서 형태의 속성을 가지는 자료로서 도수 분포표와 히스토그램으로 데이터의 분포를 확인해야하는 값들
# * 제조회사, 모델명, 변속기 종류, 구동방식, 연료종류, 자동차 종류

# %%
# 양적 자료의 데이터 분포 확인(boxplot)
data_df.boxplot(['displ','cyl','cty','hwy'])
plt.show()

# %%
# 질적 자료에 대한 데이터 빈도 확인
# 제조회사, 모델명, 변속기종류, 구동방식, 연료종류, 자동차종류
data_df['manufacturer'].value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# subaru        14
# hyundai       14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# mercury        4
# land rover     4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
data_df['model'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1                      a4
# 2                      a4
# 3                      a4
# 4                      a4
# 5                      a4
# 6                      a4
# 7                      a4
# 8              a4 quattro
# 9              a4 quattro
# 10             a4 quattro
# 11             a4 quattro
# 12             a4 quattro
# 13             a4 quattro
# 14             a4 quattro
# 15             a4 quattro
# 16             a6 quattro
# 17             a6 quattro
# 18             a6 quattro
# 19     c1500 suburban 2wd
# 20     c1500 suburban 2wd
# 21     c1500 suburban 2wd
# 22     c1500 suburban 2wd
# 23     c1500 suburban 2wd
# 24               corvette
# 25               corvette
# 26               corvette
# 27               corvette
# 28               corvette
# 29        k1500 tahoe 4wd
# 30        k1500 tahoe 4wd
#               ...
# 205     toyota tacoma 4wd
# 206     toyota tacoma 4wd
# 207     toyota tacoma 4wd
# ...

# %%
data_df['trans'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1        auto(l5)
# 2      manual(m5)
# 3      manual(m6)
# 4        auto(av)
# 5        auto(l5)
# 6      manual(m5)
# 7        auto(av)
# 8      manual(m5)
# 9        auto(l5)
# 10     manual(m6)
# 11       auto(s6)
# 12       auto(l5)
# 13     manual(m5)
# 14       auto(s6)
# 15     manual(m6)
# 16       auto(l5)
# 17       auto(s6)
# 18       auto(s6)
# 19       auto(l4)
# 20       auto(l4)
# 21       auto(l4)
# 22       auto(l4)
# 23       auto(l4)
# 24     manual(m6)
# 25       auto(l4)
# 26     manual(m6)
# 27       auto(s6)
# 28     manual(m6)
# 29       auto(l4)
# 30       auto(l4)
#           ...
# 205      auto(l4)
# 206    manual(m6)
# 207      auto(l5)
# 208    manual(m5)
# 209      auto(l4)
# 210    manual(m6)
# 211      auto(s6)
# 212    manual(m5)
# 213    manual(m5)
# 214    manual(m5)
# 215      auto(l4)
# 216      auto(s6)
# 217    manual(m6)
# 218      auto(s6)
# 219    manual(m5)
# 220      auto(l4)
# 221    manual(m5)
# ...

# %%
data_df['drv'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1      f
# 2      f
# 3      f
# 4      f
# 5      f
# 6      f
# 7      f
# 8      4
# 9      4
# 10     4
# 11     4
# 12     4
# 13     4
# 14     4
# 15     4
# 16     4
# 17     4
# 18     4
# 19     r
# 20     r
# 21     r
# 22     r
# 23     r
# 24     r
# 25     r
# 26     r
# 27     r
# 28     r
# 29     4
# 30     4
#       ..
# 205    4
# 206    4
# 207    4
# 208    f
# 209    f
# 210    f
# 211    f
# 212    f
# 213    f
# 214    f
# 215    f
# 216    f
# 217    f
# 218    f
# 219    f
# 220    f
# 221    f
# 222    f
# 223    f
# 224    f
# 225    f
# 226    f
# 227    f
# 228    f
# 229    f
# 230    f
# 231    f
# 232    f
# 233    f
# 234    f
# Name: drv, Length: 234, dtype: object>

# %%
data_df['fl'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1      p
# 2      p
# 3      p
# 4      p
# 5      p
# 6      p
# 7      p
# 8      p
# 9      p
# 10     p
# 11     p
# 12     p
# 13     p
# 14     p
# 15     p
# 16     p
# 17     p
# 18     p
# 19     r
# 20     e
# 21     r
# 22     r
# 23     r
# 24     p
# 25     p
# 26     p
# 27     p
# 28     p
# 29     r
# 30     e
#       ..
# 205    r
# 206    r
# 207    r
# 208    r
# 209    r
# 210    p
# 211    p
# 212    r
# 213    d
# 214    r
# 215    r
# 216    p
# 217    p
# 218    r
# 219    r
# 220    r
# 221    r
# 222    d
# 223    d
# 224    r
# 225    r
# 226    r
# 227    r
# 228    p
# 229    p
# 230    p
# 231    p
# 232    p
# 233    p
# 234    p
# Name: fl, Length: 234, dtype: object>

# %%
data_df['class'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1         compact
# 2         compact
# 3         compact
# 4         compact
# 5         compact
# 6         compact
# 7         compact
# 8         compact
# 9         compact
# 10        compact
# 11        compact
# 12        compact
# 13        compact
# 14        compact
# 15        compact
# 16        midsize
# 17        midsize
# 18        midsize
# 19            suv
# 20            suv
# 21            suv
# 22            suv
# 23            suv
# 24        2seater
# 25        2seater
# 26        2seater
# 27        2seater
# 28        2seater
# 29            suv
# 30            suv
#           ...
# 205        pickup
# 206        pickup
# 207        pickup
# 208       compact
# 209       compact
# 210       compact
# 211       compact
# 212       compact
# 213       compact
# 214       compact
# 215       compact
# 216       compact
# 217       compact
# 218       compact
# 219       compact
# 220       compact
# 221       compact
# ...

# %%
# 자동차 배기량(displ)에 따라서 고속도로 연비(hwy)가 다른지를 알아보자
# 배기량이 4 이하인 자동차와 5 이상인 자동차 중 어떤 자동차의 고속도로연비가 평균적으로 높은지 알아보자
data_df.query('displ <= 4')['hwy'].mean()
data_df.query('displ >= 5')['hwy'].mean()
# Out:
# 18.07894736842105

# %% [markdown]
# * hint : query()

# %%
query_df = pd.DataFrame(np.random.randint(0, 10, size=(10,3)), columns = ['col01', 'col02', 'col03'])
query_df
# Out:
#    col01  col02  col03
# 0      3      9      3
# 1      5      8      6
# 2      0      2      3
# 3      5      8      6
# 4      6      4      2
# 5      9      5      7
# 6      6      8      4
# 7      0      9      5
# 8      3      6      8
# 9      9      9      5

# %%
query_df.query('col01 >= 2 and col02 <= 5')
# Out:
#    col01  col02  col03
# 4      6      4      2
# 5      9      5      7

# %%
# 문제02 
# 자동차 제조 회사에 따라 도시 연비가 다른지 알아보려고 한다
# audi와 toyota중 어느 manufacturer의 cty가 평균적으로 더 높은지 알아보시오
data_df[data_df['manufacturer'] == 'audi']['cty'].mean()
data_df[data_df['manufacturer'] == 'toyota']['cty'].mean()

#data_df.query('manufacturer == "audi" ')['cty'].mean()
#data_df.query('manufacturer == "toyota" ')['cty'].mean()
# Out:
# 18.529411764705884

# %%
# 문제03
# chevrolet, ford, honda 자동차의 고속도로 연비 평균을 알아보려고 한다.
# 이 회사들의 데이터를 추출한 후 hwy 전체 평균을 확인하시오
data_df.query('manufacturer == "chevrolet"')['hwy'].mean()
data_df.query('manufacturer == "ford"')['hwy'].mean()
data_df.query('manufacturer == "honda"')['hwy'].mean()

manufac_car = ['chevrolet', 'ford', 'honda']
data_df.query('manufacturer in @manufac_car')['hwy'].mean()

#data_df[ (data_df['manufacturer'] == 'chevrolet') |
#         (data_df['manufacturer'] == 'ford')| 
#         (data_df['manufacturer'] == 'honda')]['hwy'].mean()

#data_df.query('manufacturer == "chevrolet" or \
#               manufacturer == "ford" or \ 
#               manufacturer == "honda")['hwy'].mean()
# Out:
# 22.50943396226415

# %%
chevrolet_index = data_df['manufacturer'] == 'chevrolet'
ford_index = data_df['manufacturer'] == 'ford'
honda_index = data_df['manufacturer'] == 'honda'

temp_df = data_df.loc[chevrolet_index | ford_index | honda_index, :]
mean_df = temp_df[['manufacturer', 'hwy']].groupby(temp_df.manufacturer).agg(np.mean)
mean_df.plot.bar()

display(mean_df)
print('세 자동차 회사 hwy의 평균 : ', temp_df['hwy'].mean())
# Out:
#                     hwy
# manufacturer
# chevrolet     21.894737
# ford          19.360000
# honda         32.555556
# 세 자동차 회사 hwy의 평균 :  22.50943396226415

# %%
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# * 데이터 전처리 : 연료가격 변수 추가(price_fl)
# * c : 가스 2.35, d : 디젤 2.38, e : 에탄올 2.11, p : 고급휘발유 2.76, r : 보통휘발유 2.22

# %%
fl_df = pd.DataFrame({
    'fl' : ['c','d','e','p','r'],
    'price_fl' : [2.35, 2.38, 2.11, 2.76, 2.22]
})
fl_df
# Out:
#   fl  price_fl
# 0  c      2.35
# 1  d      2.38
# 2  e      2.11
# 3  p      2.76
# 4  r      2.22

# %%
# 우리가 만든 연료 가격 프레임을 원본 프레임 병합
data_fl_merge_df = pd.merge(data_df, fl_df, on = 'fl', how = 'inner')
data_fl_merge_df
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 0           audi                   a4    1.8  1999    4    auto(l5)   f   18
# 1           audi                   a4    1.8  1999    4  manual(m5)   f   21
# 2           audi                   a4    2.0  2008    4  manual(m6)   f   20
# 3           audi                   a4    2.0  2008    4    auto(av)   f   21
# 4           audi                   a4    2.8  1999    6    auto(l5)   f   16
# 5           audi                   a4    2.8  1999    6  manual(m5)   f   18
# 6           audi                   a4    3.1  2008    6    auto(av)   f   18
# 7           audi           a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           audi           a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           audi           a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          audi           a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
# 머지한 데이터 프레임에서 nodel, fl, price_fl 만 추출
data_fl_merge_df[['model', 'fl', 'price_fl']]
#data_fl_merge_df.filter(['model', 'fl', 'price_fl']).head()
# Out:
#                    model fl  price_fl
# 0                     a4  p      2.76
# 1                     a4  p      2.76
# 2                     a4  p      2.76
# 3                     a4  p      2.76
# 4                     a4  p      2.76
# 5                     a4  p      2.76
# 6                     a4  p      2.76
# 7             a4 quattro  p      2.76
# 8             a4 quattro  p      2.76
# 9             a4 quattro  p      2.76
# 10            a4 quattro  p      2.76
# 11            a4 quattro  p      2.76
# 12            a4 quattro  p      2.76
# 13            a4 quattro  p      2.76
# 14            a4 quattro  p      2.76
# 15            a6 quattro  p      2.76
# 16            a6 quattro  p      2.76
# 17            a6 quattro  p      2.76
# 18              corvette  p      2.76
# 19              corvette  p      2.76
# 20              corvette  p      2.76
# 21              corvette  p      2.76
# 22              corvette  p      2.76
# 23               mustang  p      2.76
# ...

# %%
##데이터 전처리 시na값 sum으로 결측치확인
data_fl_merge_df.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# class           0
# price_fl        0
# dtype: int64

# %%
# 구동방식(drv)를 고속도로 전원(hwy) 평균
# 임의적으로 결측값 처리를 위해서 더미 값을 넣어보도록 하자
data_fl_merge_df.loc[65, 'hwy'] = np.nan
data_fl_merge_df.loc[120, 'hwy'] = np.nan
data_fl_merge_df.loc[155, 'hwy'] = np.nan
data_fl_merge_df.loc[100, 'hwy'] = np.nan
data_fl_merge_df.loc[210, 'hwy'] = np.nan
data_fl_merge_df.loc[220, 'hwy'] = np.nan

# %%
##데이터 전처리 시na값 sum으로 결측치확인
data_fl_merge_df[['drv', 'hwy']].isna().sum()
# Out:
# drv    0
# hwy    6
# dtype: int64

# %%
# hwy변수의 결측값을 제외하고, 어떤 구동방식의 고속도로평균 연비가 높은지 알아보자
data_fl_merge_isna_df = data_fl_merge_df.filter(['drv','hwy']).dropna()
print(data_fl_merge_isna_df.info())

data_fl_merge_isna_df.groupby('drv').mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 233
# Data columns (total 2 columns):
# drv    228 non-null object
# hwy    228 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.3+ KB
# None
#            hwy
# drv
# 4    19.196078
# f    28.137255
# r    21.250000

# %%
# 구동방식 별 연비평균을 비교하기 위한 막대그래프
a_df = data_fl_merge_isna_df.groupby('drv')['hwy'].mean()
a_df.plot.bar(rot=0)
plt.title('구동방식별 평균연비')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid()

# %%
# 위에서 했던 방식과 동일하게 구동방식별 고속도로와 도시연비의 평균을 구해보고
# 이를 데이터 프레임으로 만들어서 막대바를 시각화 해 보자

c_df = data_fl_merge_df.groupby('drv')['hwy','cty'].mean()
c_df.plot.bar(rot=0)

# %%
# 자동차(class)중에서 어떤 자동차가 가장 많은지 알아보려고 한다
# 종류별 빈도를 막대바로 시각화 해보자
data_fl_merge_df['class'].value_counts().plot.bar(rot=0)

# %%
# 어떤 회사에서 생산한 suv 차종의 도시연비가 높은지를 알아보려고 한다
# suv 차종을 대상으로 평균 도시연비가 가장 높은 회사 다섯곳을 막대바로 시각화 해보자

# suv_df = data_fl_merge_df[data_fl_merge_df['class'] == 'suv']
# suba_df = suv_df.sort_values(by='cty', ascending = False).head(5)
# su_df = suba_df[['cty','manufacturer']]
# new_df = su_df.set_index('manufacturer')
# new_df.plot.bar()

# 가장높은 5건을 구했네...회사별로 다시구해보자
suv_df = data_fl_merge_df.rename(columns={data_fl_merge_df.columns[10] : 'grade'})
suv_mean_df = suv_df.query("grade == 'suv'").filter(['manufacturer', 'cty']).groupby('manufacturer').mean()
suv_mean_df.sort_values('cty', ascending=False , inplace=True)
suv_mean_top5_df = suv_mean_df.head(5)

suv_mean_top5_df.plot.bar(rot=0)
plt.grid()
plt.title('제조사별 SUV 도시연비 Top 5')
plt.ylabel('연비')
plt.xlabel('제조사')
plt.show()

# %%
# 20201020
# 이상치 정제

# car_mpg 데이터에서 구동방식별 고속도로연비 평균과 도시연비 평균을 극단치를 제외하고 확인
# 각 연비별 이상치 확인 Boxplot()

outlier_df = data_df.filter(['hwy','cty'])
outlier_df.boxplot()
plt.show()

# %%
# 3사분위 정보를 얻어본다면
quantile75 = outlier_df.quantile(q=0.75)
quantile75
# Out:
# hwy    27.0
# cty    19.0
# Name: 0.75, dtype: float64

# %%
# 1사분위 정보를 얻어본다면
quantile25 = outlier_df.quantile(q=0.25)
quantile25
# Out:
# hwy    18.0
# cty    14.0
# Name: 0.25, dtype: float64

# %%
# IQR(3사분위 수 - 1사분위 수)
iqr = quantile75 - quantile25
iqr
# Out:
# hwy    9.0
# cty    5.0
# dtype: float64

# %%
# 최저 한계치(lower fence)
lower_fence = quantile25 - 1.5*iqr
print("lower fence : ",lower_fence)
# 최고 한계치(upper fence)
upper_fence = quantile75 + 1.5*iqr
print("upper fence : ",upper_fence)
# Out:
# lower fence :  hwy    4.5
# cty    6.5
# dtype: float64
# upper fence :  hwy    40.5
# cty    26.5
# dtype: float64

# %%
# 극단치 경계값을 얻어보자 (아래 수평선)
lower_outlier = outlier_df[outlier_df > lower_fence].min()
print(lower_outlier)
# 극단치 경계값을 얻어보자 (위 수평선)
upper_outlier = outlier_df[outlier_df < upper_fence].max()
print(upper_outlier)
# Out:
# hwy    12
# cty     9
# dtype: int64
# hwy    37.0
# cty    26.0
# dtype: float64

# %%
# 이상치를 결측값으로 변경
# 고속도로 연비의 이상치 데이터 추출
hwy_outlier_df = data_df.query('hwy > '+str(upper_outlier['hwy']))
hwy_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# 도시 연비의 이상치 데이터 추출
cty_outlier_df = data_df.query('cty > '+str(upper_outlier['cty']))
cty_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 100        honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 197       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 100  subcompact
# 197     compact
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# copy()
outlier_clean_df = data_df.copy()
outlier_clean_df
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 1           audi                  a4    1.8  1999    4    auto(l5)   f   18
# 2           audi                  a4    1.8  1999    4  manual(m5)   f   21
# 3           audi                  a4    2.0  2008    4  manual(m6)   f   20
# 4           audi                  a4    2.0  2008    4    auto(av)   f   21
# 5           audi                  a4    2.8  1999    6    auto(l5)   f   16
# 6           audi                  a4    2.8  1999    6  manual(m5)   f   18
# 7           audi                  a4    3.1  2008    6    auto(av)   f   18
# 8           audi          a4 quattro    1.8  1999    4  manual(m5)   4   18
# 9           audi          a4 quattro    1.8  1999    4    auto(l5)   4   16
# 10          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 11          audi          a4 quattro    2.0  2008    4    auto(s6)   4   19
# ...

# %%
# hwy 연비에 대한 이상치를 결측값으로 변경
for idx in hwy_outlier_df.index :
#     print(idx)
    outlier_clean_df.loc[idx,'hwy'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16  26.0  p  compact

# %%
# cty 연비에 대한 이상치를 결측값으로 변경
for idx in cty_outlier_df.index :
#     print(idx)
    outlier_clean_df.loc[idx,'cty'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
# 결측치 있는지 확인
outlier_clean_df.filter(['cty','hwy']).isna().sum()
# Out:
# cty    5
# hwy    3
# dtype: int64

# %%
# 결측값 제거한 구동방식별 고속도로, 도시 연비 평균
drv_mean_df = outlier_clean_df.filter(['drv', 'hwy', 'cty']).dropna().groupby('drv').mean()
drv_mean_df
# Out:
#            hwy        cty
# drv
# 4    19.174757  14.330097
# f    27.584158  19.445545
# r    21.000000  14.080000

# %%
# 시각화
drv_mean_df.plot.bar(rot=0)
plt.grid()
plt.title('이상치 제거 후 고속도로, 도시 평균 연비 비교')
plt.xlabel('구동방식')
plt.ylabel('평균연비')
plt.show()

# %%
drv_mean_df = outlier_clean_df.filter(['hwy', 'cty'])
drv_mean_df.boxplot()
plt.show()
